# %% [markdown]
# # Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
base_path = '/content/drive/MyDrive/Colab Notebooks/M2 MVA/Algorithms for Speech and NLP/Project'

# %%
# !bash "{base_path}/colab_setup.sh"
# Out:
# ...
#  [1/5] Installing system packages
# ...
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,454 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 https://cli.github.com/packages stable/main amd64 Packages [357 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [87.4 kB]
# ...

# %%
import os
with open(f"{base_path}/colab_env.sh") as f:
    for line in f:
        if line.startswith("export "):
            key, val = line.strip().removeprefix("export ").split("=", 1)
            os.environ[key] = os.path.expandvars(val)

# %% [markdown]
# # Data

# %%
# !pip install "datasets==2.21.0" huggingface_hub soundfile
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 23.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 23.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.6.1 which is incompatible.
# ...

# %%
# !cp "{base_path}/prepare_domains_asr_dataset.py" /content/

# %%
from huggingface_hub import login #, snapshot_download
login()

# %%
# !python /content/prepare_domains_asr_dataset.py \
--output_root /content/domains_asr_dataset \
--datasets mls voxpopuli commonvoice yodas \
--languages eng deu fra spa ita nld pol
# Out:
# 2026-03-23 23:07:46,649 INFO === Dataset: mls ===
# 2026-03-23 23:07:46,649 INFO   Processing mls/eng ...
# 2026-03-23 23:07:46,902 INFO NumExpr defaulting to 12 threads.
# 2026-03-23 23:07:47,624 INFO PyTorch version 2.10.0+cu128 available.
# 2026-03-23 23:07:47,626 INFO Polars version 1.35.2 available.
# 2026-03-23 23:07:47,627 INFO TensorFlow version 2.19.0 available.
# 2026-03-23 23:07:47,627 INFO JAX version 0.7.2 available.
# 2026-03-23 23:07:48,524 INFO HTTP Request: GET https://huggingface.co/api/datasets/parler-tts/mls_eng "HTTP/1.1 200 OK"
# 2026-03-23 23:07:48,940 INFO HTTP Request: GET https://huggingface.co/api/datasets/parler-tts/mls_eng "HTTP/1.1 200 OK"
# 2026-03-23 23:07:49,046 INFO HTTP Request: GET https://huggingface.co/api/datasets/parler-tts/mls_eng/revision/faf6604dcf0bb9ec0d9c280a140ad74da9c931b0 "HTTP/1.1 200 OK"
# ...

# %%
# snapshot_download(
#     repo_id="GloireLINVANI/domains_asr_dataset",
#     repo_type="dataset",
#     local_dir="/content/domains_asr_dataset",
# )

# %% [markdown]
# # Experiments

# %%
# !cp "{base_path}/evaluate_per_domain_asr.py" /content/
# !cp -r "{base_path}/domain_robustness_exp_configs" /content/

# %%
exp_configs = "/content/domain_robustness_exp_configs"

# %%
import wandb
wandb.login()
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
#  ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: gloirelinvani (gloirelinvani-institut-polytechnique-de-paris) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# %cd /content/espnet-speech_mva/espnet/egs2/ml_superb/asr1/
# Out:
# /content/espnet-speech_mva/espnet/egs2/ml_superb/asr1

# %%
duration = "10min"

# %% [markdown]
# # Track 1: Controlled per-domain performance evaluation

# %% [markdown]
# ## Exp 1: XLSR-128, all domains, frozen SSL

# %%
# !bash ./run_multi.sh --asr_config "{exp_configs}/exp1_xlsr128_all_domains_frozen_10min.yaml" --duration {duration} --lid false --only_lid false
# Out:
# 2026-03-23T09:48:06 (asr.sh:285:main) ./asr.sh --ngpu 1 --stage 1 --stop_stage 15 --nj 2 --inference_nj 1 --gpu_inference true --lang multilingual_10min_ --inference_asr_model valid.loss.ave.pth --local_data_opts --duration 10min --lid false --only_lid false --multilingual true --nlsyms_txt data/local/nlsyms.txt --nlsyms_txt data/local/nlsyms.txt --use_lm false --token_type char --feats_type raw --feats_normalize utterance_mvn --asr_config /content/experiments_configs/exp1_xlsr128_all_domains_frozen_10min.yaml --inference_config conf/decode_asr.yaml --train_set train_10min --valid_set dev_10min --test_sets test_10min --asr_tag exp1_xlsr128_all_domains_frozen_10min_multilingual_10min --asr_stats_dir exp/asr_stats_multilingual_10min --local_score_opts false false normal --skip_upload_hf false
# [INFO] /content/espnet-speech_mva/espnet/egs2/ml_superb/asr1/../../../tools/activate_python.sh is not present
# 2026-03-23T09:48:06 (asr.sh:566:main) Skipped stages:  6 7 8 9 14
# ...

# %%
# !python /content/evaluate_per_domain_asr.py \
    --ref_text data/test_10min/text \
    --hyp_text exp/asr_exp1_xlsr128_all_domains_frozen_10min_multilingual_10min/decode_asr_asr_model_valid.loss.ave/test_10min/text \
    --output exp1_xlsr128_all_domains_frozen_10min.json
# Out:
# Loaded 2564 reference utterances, 2564 hypotheses
# ...
#   PER-DOMAIN ASR EVALUATION REPORT
# ...
#
#   Overall CER: 33.64%  (2564 utterances, 184070 ref chars)
#
# ----------------------------------------------------------------------
#   PER DOMAIN
# ----------------------------------------------------------------------
#   Domain                         CER     Utts  Ref chars
#   ───────────────────────── ──────── ──────── ──────────
#   conversational              50.55%      949      48631
#   noisy_crowdsourced          27.89%      848      34685
#   parliamentary               31.14%      475      55809
#   read_speech                 22.89%      292      44945
#
#   Degradation gap (worst - best): 27.66%
#   Best domain:  read_speech (22.89%)
#   Worst domain: conversational (50.55%)
#
# ----------------------------------------------------------------------
#   PER LANGUAGE
# ----------------------------------------------------------------------
# ...

# %%
# !cp exp1_xlsr128_all_domains_frozen_10min.json "{base_path}/results/"

# %% [markdown]
# ## Exp 2: wav2vec2-large-23, all domains, frozen SSL

# %%
# !bash ./run_multi.sh --asr_config "{exp_configs}/exp2_w2v2large23_all_domains_frozen_10min.yaml" --duration {duration} --lid false --only_lid false
# Out:
# 2026-03-23T17:48:04 (asr.sh:285:main) ./asr.sh --ngpu 1 --stage 1 --stop_stage 15 --nj 2 --inference_nj 8 --gpu_inference false --lang multilingual_10min_ --inference_asr_model valid.loss.ave.pth --local_data_opts --duration 10min --lid false --only_lid false --multilingual true --nlsyms_txt data/local/nlsyms.txt --nlsyms_txt data/local/nlsyms.txt --use_lm false --token_type char --feats_type raw --feats_normalize utterance_mvn --asr_config /content/experiments_configs/exp2_w2v2large23_all_domains_frozen_10min.yaml --inference_config conf/decode_asr.yaml --train_set train_10min --valid_set dev_10min --test_sets test_10min --asr_tag exp2_w2v2large23_all_domains_frozen_10min_multilingual_10min --asr_stats_dir exp/asr_stats_multilingual_10min --local_score_opts false false normal --skip_upload_hf true
# [INFO] /content/espnet-speech_mva/espnet/egs2/ml_superb/asr1/../../../tools/activate_python.sh is not present
# 2026-03-23T17:48:04 (asr.sh:566:main) Skipped stages:  6 7 8 9 14 15
# ...

# %%
# !python /content/evaluate_per_domain_asr.py \
    --ref_text data/test_10min/text \
    --hyp_text exp/asr_exp2_w2v2large23_all_domains_frozen_10min_multilingual_10min/decode_asr_asr_model_valid.loss.ave/test_10min/text \
    --output exp2_w2v2large23_all_domains_frozen_10min.json
# Out:
# Loaded 2564 reference utterances, 2564 hypotheses
# ...
#   PER-DOMAIN ASR EVALUATION REPORT
# ...
#
#   Overall CER: 34.58%  (2564 utterances, 184070 ref chars)
#
# ----------------------------------------------------------------------
#   PER DOMAIN
# ----------------------------------------------------------------------
#   Domain                         CER     Utts  Ref chars
#   ───────────────────────── ──────── ──────── ──────────
#   conversational              49.45%      949      48631
#   noisy_crowdsourced          32.30%      848      34685
#   parliamentary               31.25%      475      55809
#   read_speech                 24.38%      292      44945
#
#   Degradation gap (worst - best): 25.07%
#   Best domain:  read_speech (24.38%)
#   Worst domain: conversational (49.45%)
#
# ----------------------------------------------------------------------
#   PER LANGUAGE
# ----------------------------------------------------------------------
# ...

# %%
# !cp exp2_w2v2large23_all_domains_frozen_10min.json "{base_path}/results/"

# %% [markdown]
# # Track 2: Domain shift robustness

# %% [markdown]
# ## Exp 3: HuBERT-base without LoRA on  Voxpopuli, Commonvoice, and Yodas.

# %%
# !bash ./run_multi.sh --asr_config "{exp_configs}/exp3_hubertbase_3_domains_frozen_10min.yaml" --duration {duration} --lid false --only_lid false
# Out:
# 2026-03-23T21:54:25 (asr.sh:285:main) ./asr.sh --ngpu 1 --stage 1 --stop_stage 15 --nj 2 --inference_nj 8 --gpu_inference false --lang multilingual_10min_ --inference_asr_model valid.loss.ave.pth --local_data_opts --duration 10min --lid false --only_lid false --multilingual true --nlsyms_txt data/local/nlsyms.txt --nlsyms_txt data/local/nlsyms.txt --use_lm false --token_type char --feats_type raw --feats_normalize utterance_mvn --asr_config /content/experiments_configs/exp3_hubertbase_3_domains_frozen_10min.yaml --inference_config conf/decode_asr.yaml --train_set train_10min --valid_set dev_10min --test_sets test_10min --asr_tag exp3_hubertbase_3_domains_frozen_10min_multilingual_10min --asr_stats_dir exp/asr_stats_multilingual_10min --local_score_opts false false normal --skip_upload_hf true
# [INFO] /content/espnet-speech_mva/espnet/egs2/ml_superb/asr1/../../../tools/activate_python.sh is not present
# 2026-03-23T21:54:25 (asr.sh:566:main) Skipped stages:  6 7 8 9 14 15
# ...

# %%
# !python /content/evaluate_per_domain_asr.py \
    --ref_text data/test_10min/text \
    --hyp_text exp/asr_exp3_hubertbase_3_domains_frozen_10min_multilingual_10min/decode_asr_asr_model_valid.loss.ave/test_10min/text \
    --output exp3_hubertbase_3_domains_frozen_10min.json
# Out:
# Loaded 2272 reference utterances, 2272 hypotheses
# ...
#   PER-DOMAIN ASR EVALUATION REPORT
# ...
#
#   Overall CER: 46.76%  (2272 utterances, 139125 ref chars)
#
# ----------------------------------------------------------------------
#   PER DOMAIN
# ----------------------------------------------------------------------
#   Domain                         CER     Utts  Ref chars
#   ───────────────────────── ──────── ──────── ──────────
#   conversational              57.67%      949      48631
#   noisy_crowdsourced          40.88%      848      34685
#   parliamentary               40.90%      475      55809
#
#   Degradation gap (worst - best): 16.78%
#   Best domain:  noisy_crowdsourced (40.88%)
#   Worst domain: conversational (57.67%)
#
# ----------------------------------------------------------------------
#   PER LANGUAGE
# ----------------------------------------------------------------------
#   Language                       CER     Utts  Ref chars
# ...

# %%
# !cp exp3_hubertbase_3_domains_frozen_10min.json "{base_path}/results/"

# %% [markdown]
# ## Exp 4: HuBERT-base with LoRA on  Voxpopuli, Commonvoice, and Yodas.

# %%
# !bash ./run_multi.sh --asr_config "{exp_configs}/exp4_hubertbase_3_domains_lora_10min.yaml" --duration {duration} --lid false --only_lid false
# Out:
# 2026-03-23T23:34:23 (asr.sh:285:main) ./asr.sh --ngpu 1 --stage 1 --stop_stage 15 --nj 32 --inference_nj 8 --gpu_inference false --lang multilingual_10min_ --inference_asr_model valid.loss.ave.pth --local_data_opts --duration 10min --lid false --only_lid false --multilingual true --nlsyms_txt data/local/nlsyms.txt --nlsyms_txt data/local/nlsyms.txt --use_lm false --token_type char --feats_type raw --feats_normalize utterance_mvn --asr_config /content/experiments_configs/exp4_hubertbase_3_domains_lora_10min.yaml --inference_config conf/decode_asr.yaml --train_set train_10min --valid_set dev_10min --test_sets test_10min --asr_tag exp4_hubertbase_3_domains_lora_10min_multilingual_10min --asr_stats_dir exp/asr_stats_multilingual_10min --local_score_opts false false normal --skip_upload_hf false
# [INFO] /content/espnet-speech_mva/espnet/egs2/ml_superb/asr1/../../../tools/activate_python.sh is not present
# 2026-03-23T23:34:23 (asr.sh:566:main) Skipped stages:  6 7 8 9 14
# ...

# %%
# !python /content/evaluate_per_domain_asr.py \
    --ref_text data/test_10min/text \
    --hyp_text exp/asr_exp4_hubertbase_3_domains_lora_10min_multilingual_10min/decode_asr_asr_model_valid.loss.ave/test_10min/text \
    --output exp4_hubertbase_3_domains_lora_10min.json
# Out:
# Loaded 2272 reference utterances, 2272 hypotheses
# ...
#   PER-DOMAIN ASR EVALUATION REPORT
# ...
#
#   Overall CER: 46.64%  (2272 utterances, 139125 ref chars)
#
# ----------------------------------------------------------------------
#   PER DOMAIN
# ----------------------------------------------------------------------
#   Domain                         CER     Utts  Ref chars
#   ───────────────────────── ──────── ──────── ──────────
#   conversational              57.69%      949      48631
#   noisy_crowdsourced          40.57%      848      34685
#   parliamentary               40.79%      475      55809
#
#   Degradation gap (worst - best): 17.12%
#   Best domain:  noisy_crowdsourced (40.57%)
#   Worst domain: conversational (57.69%)
#
# ----------------------------------------------------------------------
#   PER LANGUAGE
# ----------------------------------------------------------------------
#   Language                       CER     Utts  Ref chars
# ...

# %%
# !cp exp4_hubertbase_3_domains_lora_10min.json "{base_path}/results/"

# %% [markdown]
# # Track 3: Cross-domain generalization

# %% [markdown]
# ## Exp 5: XLSR-128 frozen trained and validated on MLS and Voxpopuli, tested on Commonvoice and Yodas.

# %%
# !sed -i 's/test_set="test_${duration}${suffix}"/test_set="${train_dev} test_${duration}${suffix}"/' "/content/espnet-speech_mva/espnet/egs2/ml_superb/asr1/run_multi.sh"

# %%
# !bash ./run_multi.sh --asr_config "{exp_configs}/exp5_xlsr128_easy2hard_10min.yaml" --duration {duration} --lid false --only_lid false
# Out:
# 2026-03-24T01:41:03 (asr.sh:285:main) ./asr.sh --ngpu 1 --stage 1 --stop_stage 15 --nj 32 --inference_nj 8 --gpu_inference false --lang multilingual_10min_ --inference_asr_model valid.loss.ave.pth --local_data_opts --duration 10min --lid false --only_lid false --multilingual true --nlsyms_txt data/local/nlsyms.txt --nlsyms_txt data/local/nlsyms.txt --use_lm false --token_type char --feats_type raw --feats_normalize utterance_mvn --asr_config /content/experiments_configs/exp5_xlsr128_easy2hard_10min.yaml --inference_config conf/decode_asr.yaml --train_set train_10min --valid_set dev_10min --test_sets dev_10min test_10min --asr_tag exp5_xlsr128_easy2hard_10min_multilingual_10min --asr_stats_dir exp/asr_stats_multilingual_10min --local_score_opts false false normal --skip_upload_hf false
# [INFO] /content/espnet-speech_mva/espnet/egs2/ml_superb/asr1/../../../tools/activate_python.sh is not present
# ...

# %%
# Validation set
# !python /content/evaluate_per_domain_asr.py \
    --ref_text data/dev_10min/text \
    --hyp_text exp/asr_exp5_xlsr128_easy2hard_10min_multilingual_10min/decode_asr_asr_model_valid.loss.ave/org/dev_10min/text \
    --output exp5_xlsr128_easy2hard_10min_dev.json
# Out:
# Loaded 779 reference utterances, 779 hypotheses
# ...
#   PER-DOMAIN ASR EVALUATION REPORT
# ...
#
#   Overall CER: 29.57%  (779 utterances, 106651 ref chars)
#
# ----------------------------------------------------------------------
#   PER DOMAIN
# ----------------------------------------------------------------------
#   Domain                         CER     Utts  Ref chars
#   ───────────────────────── ──────── ──────── ──────────
#   parliamentary               29.91%      486      56853
#   read_speech                 29.19%      293      49798
#
#   Degradation gap (worst - best): 0.71%
#   Best domain:  read_speech (29.19%)
#   Worst domain: parliamentary (29.91%)
#
# ----------------------------------------------------------------------
#   PER LANGUAGE
# ----------------------------------------------------------------------
#   Language                       CER     Utts  Ref chars
#   ───────────────────────── ──────── ──────── ──────────
# ...

# %%
# !cp exp5_xlsr128_easy2hard_10min_dev.json "{base_path}/results/"

# %%
# Test set
# !python /content/evaluate_per_domain_asr.py \
    --ref_text data/test_10min/text \
    --hyp_text exp/asr_exp5_xlsr128_easy2hard_10min_multilingual_10min/decode_asr_asr_model_valid.loss.ave/test_10min/text \
    --output exp5_xlsr128_easy2hard_10min_test.json
# Out:
# Loaded 1797 reference utterances, 1797 hypotheses
# ...
#   PER-DOMAIN ASR EVALUATION REPORT
# ...
#
#   Overall CER: 44.21%  (1797 utterances, 83316 ref chars)
#
# ----------------------------------------------------------------------
#   PER DOMAIN
# ----------------------------------------------------------------------
#   Domain                         CER     Utts  Ref chars
#   ───────────────────────── ──────── ──────── ──────────
#   conversational              51.40%      949      48631
#   noisy_crowdsourced          34.14%      848      34685
#
#   Degradation gap (worst - best): 17.25%
#   Best domain:  noisy_crowdsourced (34.14%)
#   Worst domain: conversational (51.40%)
#
# ----------------------------------------------------------------------
#   PER LANGUAGE
# ----------------------------------------------------------------------
#   Language                       CER     Utts  Ref chars
#   ───────────────────────── ──────── ──────── ──────────
# ...

# %%
# !cp exp5_xlsr128_easy2hard_10min_test.json "{base_path}/results/"

# %% [markdown]
# ## Exp 6: XLSR-53 frozen trained and validated on MLS and Voxpopuli, tested on Commonvoice and Yodas.

# %%
# !bash ./run_multi.sh --asr_config "{exp_configs}/exp6_xlsr53_easy2hard_10min.yaml" --duration {duration} --lid false --only_lid false
# Out:
# 2026-03-24T03:56:27 (asr.sh:285:main) ./asr.sh --ngpu 1 --stage 1 --stop_stage 15 --nj 32 --inference_nj 8 --gpu_inference false --lang multilingual_10min_ --inference_asr_model valid.loss.ave.pth --local_data_opts --duration 10min --lid false --only_lid false --multilingual true --nlsyms_txt data/local/nlsyms.txt --nlsyms_txt data/local/nlsyms.txt --use_lm false --token_type char --feats_type raw --feats_normalize utterance_mvn --asr_config /content/experiments_configs/exp6_xlsr53_easy2hard_10min.yaml --inference_config conf/decode_asr.yaml --train_set train_10min --valid_set dev_10min --test_sets dev_10min test_10min --asr_tag exp6_xlsr53_easy2hard_10min_multilingual_10min --asr_stats_dir exp/asr_stats_multilingual_10min --local_score_opts false false normal --skip_upload_hf false
# [INFO] /content/espnet-speech_mva/espnet/egs2/ml_superb/asr1/../../../tools/activate_python.sh is not present
# ...

# %%
# Validation set
# !python /content/evaluate_per_domain_asr.py \
    --ref_text data/dev_10min/text \
    --hyp_text exp/asr_exp6_xlsr53_easy2hard_10min_multilingual_10min/decode_asr_asr_model_valid.loss.ave/org/dev_10min/text \
    --output exp6_xlsr53_easy2hard_10min_dev.json
# Out:
# Loaded 779 reference utterances, 779 hypotheses
# ...
#   PER-DOMAIN ASR EVALUATION REPORT
# ...
#
#   Overall CER: 34.44%  (779 utterances, 106651 ref chars)
#
# ----------------------------------------------------------------------
#   PER DOMAIN
# ----------------------------------------------------------------------
#   Domain                         CER     Utts  Ref chars
#   ───────────────────────── ──────── ──────── ──────────
#   parliamentary               35.56%      486      56853
#   read_speech                 33.16%      293      49798
#
#   Degradation gap (worst - best): 2.40%
#   Best domain:  read_speech (33.16%)
#   Worst domain: parliamentary (35.56%)
#
# ----------------------------------------------------------------------
#   PER LANGUAGE
# ----------------------------------------------------------------------
#   Language                       CER     Utts  Ref chars
#   ───────────────────────── ──────── ──────── ──────────
# ...

# %%
# !cp exp6_xlsr53_easy2hard_10min_dev.json "{base_path}/results/"

# %%
# Test set
# !python /content/evaluate_per_domain_asr.py \
    --ref_text data/test_10min/text \
    --hyp_text exp/asr_exp6_xlsr53_easy2hard_10min_multilingual_10min/decode_asr_asr_model_valid.loss.ave/test_10min/text \
    --output exp6_xlsr53_easy2hard_10min_test.json
# Out:
# Loaded 1797 reference utterances, 1797 hypotheses
# ...
#   PER-DOMAIN ASR EVALUATION REPORT
# ...
#
#   Overall CER: 48.53%  (1797 utterances, 83316 ref chars)
#
# ----------------------------------------------------------------------
#   PER DOMAIN
# ----------------------------------------------------------------------
#   Domain                         CER     Utts  Ref chars
#   ───────────────────────── ──────── ──────── ──────────
#   conversational              55.77%      949      48631
#   noisy_crowdsourced          38.39%      848      34685
#
#   Degradation gap (worst - best): 17.38%
#   Best domain:  noisy_crowdsourced (38.39%)
#   Worst domain: conversational (55.77%)
#
# ----------------------------------------------------------------------
#   PER LANGUAGE
# ----------------------------------------------------------------------
#   Language                       CER     Utts  Ref chars
#   ───────────────────────── ──────── ──────── ──────────
# ...

# %%
# !cp exp6_xlsr53_easy2hard_10min_test.json "{base_path}/results/"
